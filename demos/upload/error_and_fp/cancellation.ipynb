# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
for p in np.arange(0,10):
    x = 10**p
    f1 = x * (np.sqrt(x+1) - np.sqrt(x))
    f2 = x / (np.sqrt(x+1) + np.sqrt(x))
    print(f"{x:>10} {f1:>20} {f2:>20} {f1-f2:>20}")
# Out:
#          1  0.41421356237309515   0.4142135623730951 5.551115123125783e-17
#         10   1.5434713018702029    1.543471301870205 -2.220446049250313e-15
#        100    4.987562112088995    4.987562112089027 -3.2862601528904634e-14
#       1000   15.807437428957627   15.807437428955824 1.8030021919912542e-12
#      10000    49.99875006248544    49.99875006249609 -1.0651035609043902e-11
#     100000    158.1134877255863   158.11348772568783 -1.0152234608540311e-10
#    1000000    499.9998750463419    499.9998750000625 4.627941052604001e-08
#   10000000   1581.1387902431306   1581.1387905557208 -3.1259014576789923e-07
#  100000000    5000.000055588316    4999.999987499999 6.808831676607952e-05
# 1000000000   15811.390767339617    15811.38829688905 0.0024704505667614285

# %%
### x=np.linspace(0.99998, 1.00002, 100)

#f = (x-1)**3
#f = x**3 - 3*x**2 + 3*x - 1
f = -1+x*(3+x*(-3+x))
plt.plot(x, f, 'o')
